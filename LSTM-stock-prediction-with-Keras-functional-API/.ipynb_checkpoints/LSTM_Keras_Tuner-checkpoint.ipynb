# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
import yfinance as yf
from yahoofinancials import YahooFinancials
# %matplotlib inline

# %%
appl_df = yf.download('AAPL', 
                      start='2019-01-01', 
                      end='2020-12-31', 
                      progress=False)

# %%
appl_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.277527  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.464806  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  35.936085  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  35.856094  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.539623  164101200

# %%
appl_df['Open'].plot(title="Apple's stock price")
# Out:
# <AxesSubplot:title={'center':"Apple's stock price"}, xlabel='Date'>

# %%
appl_df['Open']=appl_df['Open'].pct_change()
appl_df['Open'].plot(title="Apple's stock return")
# Out:
# <AxesSubplot:title={'center':"Apple's stock return"}, xlabel='Date'>

# %%
sc = StandardScaler()

# %%
def preproc( data, lag, ratio):
    data=data.dropna().iloc[:, 0:1]
    Dates=data.index.unique()
    data.iloc[:, 0] = sc.fit_transform(data.iloc[:, 0].values.reshape(-1, 1))
    for s in range(1, lag):
        data['shift_{}'.format(s)] = data.iloc[:, 0].shift(s)
    X_data = data.dropna().drop(['Open'], axis=1)
    y_data = data.dropna()[['Open']]
    index=int(round(len(X_data)*ratio))
    X_data_train=X_data.iloc[:index,:]
    X_data_test =X_data.iloc[index+1:,:]
    y_data_train=y_data.iloc[:index,:]
    y_data_test =y_data.iloc[index+1:,:]
    return X_data_train,X_data_test,y_data_train,y_data_test,Dates;

# %%
a,b,c,d,e=preproc(appl_df, 25, 0.90)

# %%
a = a.values
b= b.values
c = c.values
d = d.values

# %%
X_train_t = a.reshape(a.shape[0], 1, 24)
X_test_t = b.reshape(b.shape[0], 1, 24)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import keras.backend as K
from keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow.keras.layers import Dropout
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

# %%
K.clear_session()
early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
model = Sequential()
model.add(LSTM(12, input_shape=(1, 24), return_sequences=True))
model.add(LSTM(6))
model.add(Dense(6))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train_t, c,
          epochs=100, batch_size=1, verbose=1,
          callbacks=[early_stop])
# Out:
# Epoch 1/100
# 431/431 [==============================] - 2s 987us/step - loss: 1.2000
# Epoch 2/100
# 431/431 [==============================] - 0s 962us/step - loss: 0.8588
# Epoch 3/100
# 431/431 [==============================] - 0s 998us/step - loss: 0.9963
# Epoch 4/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.9857
# Epoch 5/100
# 431/431 [==============================] - 0s 960us/step - loss: 0.7688
# Epoch 6/100
# 431/431 [==============================] - 0s 978us/step - loss: 0.6535
# Epoch 7/100
# 431/431 [==============================] - 0s 989us/step - loss: 0.5950
# Epoch 8/100
# 431/431 [==============================] - 0s 993us/step - loss: 0.4712
# Epoch 9/100
# 431/431 [==============================] - 0s 998us/step - loss: 0.4020
# Epoch 10/100
# 431/431 [==============================] - 0s 995us/step - loss: 0.3642
# Epoch 11/100
# 431/431 [==============================] - 0s 963us/step - loss: 0.2672
# Epoch 12/100
# 431/431 [==============================] - 0s 960us/step - loss: 0.2978
# Epoch 13/100
# 431/431 [==============================] - 0s 961us/step - loss: 0.2939
# Epoch 14/100
# 431/431 [==============================] - 0s 963us/step - loss: 0.2034
# Epoch 15/100
# 431/431 [==============================] - 0s 997us/step - loss: 0.2183
# Epoch 16/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1932
# Epoch 17/100
# 431/431 [==============================] - 0s 995us/step - loss: 0.1844
# Epoch 18/100
# 431/431 [==============================] - 0s 973us/step - loss: 0.1769
# Epoch 19/100
# 431/431 [==============================] - 0s 974us/step - loss: 0.1671
# Epoch 20/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1217
# Epoch 21/100
# 431/431 [==============================] - 0s 986us/step - loss: 0.1353
# Epoch 22/100
# 431/431 [==============================] - 0s 994us/step - loss: 0.1309
# Epoch 23/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1272
# Epoch 24/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1588
# Epoch 25/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1311
# Epoch 26/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1155
# Epoch 27/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1218
# Epoch 28/100
# 431/431 [==============================] - 0s 1ms/step - loss: 0.1040
# Epoch 29/100
# 431/431 [==============================] - 0s 995us/step - loss: 0.1127
# Epoch 30/100
# 431/431 [==============================] - 0s 991us/step - loss: 0.0892
# Epoch 00030: early stopping

# %%
def build_model(hp):
    model = Sequential()
    model.add(LSTM(hp.Int('input_unit',min_value=32,max_value=128,step=32),return_sequences=True, input_shape=(1,24)))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units',min_value=32,max_value=128,step=32),return_sequences=True))
    model.add(LSTM(6))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(Dense(6))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam',metrics = ['mse'])
    return model

# %%
tuner= kt.RandomSearch(
        build_model,
        objective='mse',
        max_trials=5,
        executions_per_trial=1
        )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
tuner.search(
        x=X_train_t,
        y=c,
        epochs=20,
        batch_size=128,
        validation_data=(X_test_t,d),
)
# Out:
# Trial 2 Complete [00h 00m 08s]
# mse: 0.9439128637313843
#
# Best mse So Far: 0.888340413570404
# Total elapsed time: 00h 00m 16s
# INFO:tensorflow:Oracle triggered exit

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 64)             22784
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 96)             61824
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 32)             16512
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 32)             8320
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 6)                 936
# _________________________________________________________________
# dropout (Dropout)            (None, 6)                 0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 42
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 110,425
# Trainable params: 110,425
# Non-trainable params: 0
# _________________________________________________________________
