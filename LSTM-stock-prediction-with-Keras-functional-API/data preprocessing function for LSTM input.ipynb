# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
sc = MinMaxScaler(feature_range = (0, 1))

# %%
def preproc( data, lag, ratio):
    data=data.dropna().iloc[:, 0:2]
    Dates=data["Date"].unique()
    data.iloc[:, 1] = sc.fit_transform(data.iloc[:, 1].values.reshape(-1, 1))
    for s in range(1, lag):
        data['shift_{}'.format(s)] = data['Open'].shift(s)
    X_data = data.dropna().drop(['Open',"Date"], axis=1)
    y_data = data.dropna()[['Open']]
    index=int(round(len(X_data)*ratio))
    X_data_train=X_data.iloc[:index,:]
    X_data_test =X_data.iloc[index+1:,:]
    y_data_train=y_data.iloc[:index,:]
    y_data_test =y_data.iloc[index+1:,:]
    return X_data_train,X_data_test,y_data_train,y_data_test,Dates;

# %%
data25 = pd.read_csv('EURUSDX.csv')
a,b,c,d,e=preproc(data25, 15, 0.75)

# %%
def preproc2( data1, data2, lag, ratio):
    common_dates=list(set(data1["Date"]) & set(data2["Date"]))
    data1=data1[data1['Date'].isin(common_dates)]
    data2=data2[data2['Date'].isin(common_dates)]
    X1=preproc(data1, lag, ratio)
    X2=preproc(data2, lag, ratio)
    return X1,X2;

# %%
data1 = pd.read_csv('EURUSDX.csv')
data2 = pd.read_csv('TNX.csv')
dataLSTM=preproc2( data1, data2, 15, 0.75)
dataLSTM[1][3]
# Out:
#          Open
# 232  0.418895
# 233  0.432561
# 235  0.452169
# 236  0.441474
# 237  0.453357
# 238  0.431373
# 239  0.481878
# 241  0.464646
# 242  0.471777
# 243  0.489602
# 244  0.522876
# 245  0.515746
# 247  0.502080
# 249  0.502080
# 250  0.490790
# 252  0.508616
# 253  0.493761
# 254  0.496732
# 255  0.452169
# 257  0.426619
# 258  0.433749
# 259  0.449198
# 260  0.476530
# 261  0.467023
# 263  0.455734
# 264  0.460487
# 265  0.432561
# 266  0.424242
# 267  0.446227
# 269  0.433749
# 270  0.426619
# 271  0.399881
# 272  0.396316
# 274  0.323827
# 275  0.330957
# 276  0.338681
# 277  0.298871
# 278  0.286988
# 280  0.289958
# 281  0.303030
# 282  0.348188
# 283  0.338681
# 284  0.326203
# 286  0.298871
# 287  0.313725
# 288  0.331551
# 289  0.317885
# 290  0.316102
# 292  0.283422
# 293  0.294712
# 294  0.279263
# 295  0.248366
# 297  0.195484
# 298  0.182412
# 299  0.179441
# 300  0.121806
# 301  0.085561
# 303  0.000000
